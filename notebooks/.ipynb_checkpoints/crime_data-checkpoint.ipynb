# %%
import pyspark as ps
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

# %%
spark = (ps.sql.SparkSession
         .builder
         .master('local[4]')
         .appName('crime_data')
         .getOrCreate()
        )
sc = spark.sparkContext

# %%
spark_arrests = spark.read.csv('../data/DOJ_ArrestData1980-2019.csv',
                    header=True,
                    quote='"',
                    sep=",",
                    inferSchema=True)

# %%
spark_arrests.createOrReplaceTempView('arrests_tempview')

# %%
query = '''
select YEAR, COUNTY, SUM(VIOLENT) AS violent_crime_arrests
from arrests_tempview
where YEAR > 2002
and YEAR < 2019
AND `COUNTY` != 'San Francisco County'
AND `COUNTY` NOT IN ('Alpine County', 'Yolo County', 'Yuba County', 'Fresno County', 'Placer County'
, 'Sutter County', 'Mono County', 'Tuolumne County', 'Plumas County', 'Sierra County', 'San Bernardino County'
, 'Merced County', 'Santa Clara County')
GROUP BY YEAR, COUNTY
ORDER BY YEAR, COUNTY
'''

arrests_sql = spark.sql(query)
arrests_sql.show(5)
arrests_pd = arrests_sql.toPandas()
# Out:
# +----+----------------+---------------------+
# |YEAR|          COUNTY|violent_crime_arrests|
# +----+----------------+---------------------+
# |2003|  Alameda County|                 4749|
# |2003|   Amador County|                   92|
# |2003|    Butte County|                  571|
# |2003|Calaveras County|                  166|
# |2003|   Colusa County|                   83|
# +----+----------------+---------------------+
# only showing top 5 rows

# %%
arrests_pd.tail(5)
# Out:
#      YEAR           COUNTY  violent_crime_arrests
# 907  2018    Tulare County                   2322
# 908  2018  Tuolumne County                    203
# 909  2018   Ventura County                   2271
# 910  2018      Yolo County                    575
# 911  2018      Yuba County                    391

# %%
spark_population = spark.read.csv('../data/population_by_county_1970_to_2018.csv',
                    header=True,
                    quote='"',
                    sep=",",
                    inferSchema=True)

# %%
spark_population.createOrReplaceTempView('population_tempview')

# %%
query = '''
select `Year`, `County`, `Population`
from population_tempview
WHERE `County` != 'None'
AND `County` != 'San Francisco'
AND `County` NOT IN ('Alpine', 'Yolo', 'Yuba', 'Fresno', 'Placer', 'Sutter', 'Mono', 'Tuolumne', 'Plumas', 'Sierra', 'San Bernardino', 'Merced', 'Santa Clara')
AND `Year` > 2002
AND `Year` < 2019
'''

population_sql = spark.sql(query)
population_sql.show()
population_pd = population_sql.toPandas()
# Out:
# +----+------------+----------+
# |Year|      County|Population|
# +----+------------+----------+
# |2003|     Alameda|   1467892|
# |2003|      Amador|     36656|
# |2003|       Butte|    209389|
# |2003|   Calaveras|     42651|
# |2003|      Colusa|     19538|
# |2003|Contra Costa|    984256|
# |2003|   Del Norte|     27744|
# |2003|   El Dorado|    166195|
# |2003|       Glenn|     26974|
# |2003|    Humboldt|    129468|
# |2003|    Imperial|    149041|
# |2003|        Inyo|     18461|
# |2003|        Kern|    707111|
# |2003|       Kings|    136710|
# |2003|        Lake|     61492|
# |2003|      Lassen|     33828|
# |2003| Los Angeles|   9756914|
# |2003|      Madera|    130641|
# |2003|       Marin|    247342|
# |2003|    Mariposa|     17612|
# +----+------------+----------+
# only showing top 20 rows

# %%
population_pd
# Out:
#      Year      County  Population
# 0    2003     Alameda     1467892
# 1    2003      Amador       36656
# 2    2003       Butte      209389
# 3    2003   Calaveras       42651
# 4    2003      Colusa       19538
# ..    ...         ...         ...
# 699  2018  Stanislaus      555624
# 700  2018      Tehama       64039
# 701  2018     Trinity       13635
# 702  2018      Tulare      475834
# 703  2018     Ventura      859073
#
# [704 rows x 3 columns]

# %%
#arrests_per_capita_pd = arrests_pd.join(population_pd)
#arrests_per_capita_pd['COUNTY'] = arrests_per_capita_pd['County']
#arrests_per_capita_pd.drop('Year', axis=1, inplace=True)
#arrests_per_capita_pd.drop('County', axis=1, inplace=True)
#arrests_per_capita_pd['arrests_per_capita'] = arrests_per_capita_pd['violent_crime_arrests'] / arrests_per_capita_pd['Population']
#arrests_per_capita_pd.rename(columns = {'YEAR': 'Year', 'COUNTY': 'County', 'violent_crime_arrests': 'Violent Crime Arrests', 'arrests_per_capita': 'Arrests Per Capita', 'Population': 'Estimated Population'}, inplace=True)

arrests_per_capita_pd.head(600)
# Out:
#      Year      County  Violent Crime Arrests  Estimated Population  \
# 0    2003     Alameda                   4749               1467892
# 1    2003      Amador                     92                 36656
# 2    2003       Butte                    571                209389
# 3    2003   Calaveras                    166                 42651
# 4    2003      Colusa                     83                 19538
# ..    ...         ...                    ...                   ...
# 595  2016        Napa                    385                141711
# 596  2016      Nevada                    181                 98520
# 597  2016      Orange                   6019               3172222
# 598  2016   Riverside                   5742               2346717
# 599  2016  Sacramento                   5005               1495611
#
#      Arrests Per Capita
# 0              0.003235
# 1              0.002510
# 2              0.002727
# 3              0.003892
# 4              0.004248
# ...

# %%
arrests_dict = {}
for year in arrests_per_capita_pd['Year'].unique():
    arrests_dict[year] = list(arrests_per_capita_pd[arrests_per_capita_pd.Year==year]['Arrests Per Capita'].values)

# %%
fig, ax = plt.subplots(figsize=(10, 15))
ax.boxplot(arrests_dict.values(), vert=False, showfliers=False, patch_artist=True,
            boxprops=dict(facecolor='lightgrey', color='black'),
            capprops=dict(color='black'),
            whiskerprops=dict(color='black'),
            flierprops=dict(color='red', markeredgecolor='red'),
            medianprops=dict(color='red'))

ax.set_yticklabels(arrests_dict.keys(), fontsize=12)
ax.set_xlabel('Annual Arrests Per Capita', fontsize=15, labelpad=5)
ax.set_title('Violent Crime Arrests By County 2003-2018', fontsize=25, pad=15)
ax.grid(linestyle=':')
fig.tight_layout()
#plt.savefig('../images/arrests box plot')

# %%
avg_arrests_per_year = arrests_per_capita_pd.groupby('Year').mean().reset_index()
avg_arrests_per_year.head(20)
# Out:
#     Year  Violent Crime Arrests  Estimated Population  Arrests Per Capita
# 0   2003            2383.227273         661592.636364            0.003900
# 1   2004            2303.068182         668742.090909            0.003864
# 2   2005            2270.272727         673605.568182            0.003757
# 3   2006            2280.681818         677335.704545            0.003798
# 4   2007            2343.090909         681766.886364            0.003662
# 5   2008            2319.659091         686860.136364            0.003517
# 6   2009            2258.931818         691474.295455            0.003477
# 7   2010            2129.477273         696069.136364            0.003403
# 8   2011            2008.136364         700960.272727            0.003257
# 9   2012            1967.613636         707182.840909            0.003327
# 10  2013            1873.136364         713622.272727            0.003265
# 11  2014            1957.931818         719756.090909            0.003299
# ...

# %% [markdown]
# total_arrests_per_year = arrests_per_capita_pd.groupby('Year').sum().reset_index()
# total_arrests_per_year.head(16)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.plot(total_arrests_per_year['Year'], total_arrests_per_year['Arrests Per Capita'], label='All Counties', color='darkorange')
ax.set_ylabel('Annual Arrests Per Capita', fontsize=20)
ax.set_xlabel('Year', fontsize=20)
ax.set_title('Total Annual Arrests Per Capita for All Observed Counties', fontsize=25)
#plt.savefig('Arrests Per Capita for All Counties')

# %%
priority_police = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Inyo', 'Mariposa', 'Colusa', 'Amador', 'Trinity', 'Modoc',
                       'Siskiyou', 'Glenn', 'Calaveras', 'Napa']:
    priority_police = pd.concat([priority_police, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
priority_police.head(5)
# Out:
#      Year County Violent Crime Arrests Estimated Population  \
# 11   2003   Inyo                    61                18461
# 55   2004   Inyo                    79                18533
# 99   2005   Inyo                    75                18511
# 143  2006   Inyo                    67                18442
# 187  2007   Inyo                    68                18434
#
#      Arrests Per Capita
# 11             0.003304
# 55             0.004263
# 99             0.004052
# 143            0.003633
# 187            0.003689

# %%
priority_mentalhealth = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Trinity', 'Modoc', 'Siskiyou', 'Glenn', 'Mendocino',
                       'Humboldt', 'Inyo', 'Colusa', 'Santa Cruz', 'Del Norte']:
    priority_mentalhealth = pd.concat([priority_mentalhealth, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
priority_mentalhealth.head(5)
# Out:
#      Year   County Violent Crime Arrests Estimated Population  \
# 41   2003  Trinity                    82                13273
# 85   2004  Trinity                    81                13453
# 129  2005  Trinity                    79                13654
# 173  2006  Trinity                    67                13806
# 217  2007  Trinity                    54                13806
#
#      Arrests Per Capita
# 41             0.006178
# 85             0.006021
# 129            0.005786
# 173            0.004853
# 217            0.003911

# %%
priority_substanceabuse = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Modoc', 'Trinity', 'Glenn', 'Lake', 'Inyo', 'Mariposa',
                       'Colusa', 'Lassen', 'Napa', 'Sonoma']:
    priority_substanceabuse = pd.concat([priority_substanceabuse, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
priority_substanceabuse.groupby('Year').mean('Arrests Per Capita').reset_index()
# Out:
#     Year  Arrests Per Capita
# 0   2003            0.004176
# 1   2004            0.004194
# 2   2005            0.004321
# 3   2006            0.004167
# 4   2007            0.003881
# 5   2008            0.003601
# 6   2009            0.003780
# 7   2010            0.003872
# 8   2011            0.003786
# 9   2012            0.004294
# 10  2013            0.004004
# 11  2014            0.003835
# 12  2015            0.003813
# 13  2016            0.004133
# 14  2017            0.004192
# 15  2018            0.004056

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_ylabel('Avg Annual Arrests Per Capita', fontsize=20)
ax.set_xlabel('Year', fontsize=20)
ax.set_title('Average Annual Arrests Per Capita by Budget Prioritization', fontsize=25)

#ax.plot(avg_arrests_per_year['Year'], 
#        avg_arrests_per_year['Arrests Per Capita'],
#        label='Statewide Average', color='darkorange', linewidth=5)
sns.regplot(avg_arrests_per_year['Year'], 
        avg_arrests_per_year['Arrests Per Capita'],
            fit_reg=True, color='darkorange', label='Statewide Average', marker='o')

#ax.plot(priority_police.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
#        priority_police.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'], 
#        label='Police', color='lightskyblue')
sns.regplot(priority_police.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
        priority_police.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'],
           fit_reg=True, color='lightskyblue', label='Police', marker='o')

#ax.plot(priority_mentalhealth.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
#        priority_mentalhealth.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'], 
#        label='Mental Health', color='plum')
sns.regplot(priority_mentalhealth.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
        priority_mentalhealth.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'],
            fit_reg=True, color='plum', label='Mental Health', marker='o')

#ax.plot(priority_substanceabuse.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
#        priority_substanceabuse.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'], 
#        label='Substance Abuse', color='mediumaquamarine')
sns.regplot(priority_substanceabuse.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
        priority_substanceabuse.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'],
           fit_reg=True, color='mediumaquamarine', label='Substance Abuse', marker='o')

ax.legend()

plt.savefig('Budget Prioritization Compared to Avg Annual Arrests Scatter With Trend Lines')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
first_5yravg_crime = pd.DataFrame(arrests_per_capita_pd[0:220].groupby('County').mean()['Arrests Per Capita']).reset_index()
first_5yravg_crime.rename(columns={'Arrests Per Capita':'Avg of First 5 Years'}, inplace=True)

# %%
last_5yravg_crime = pd.DataFrame(arrests_per_capita_pd[380:600].groupby('County').mean()['Arrests Per Capita']).reset_index()
last_5yravg_crime.rename(columns={'County':'County2', 'Arrests Per Capita':'Avg of Last 5 Years'}, inplace=True)

# %%
crime_diff = pd.concat([first_5yravg_crime, last_5yravg_crime], axis=1)
crime_diff.drop(columns='County2', inplace=True)
crime_diff['Difference'] = crime_diff['Avg of First 5 Years'] - crime_diff['Avg of Last 5 Years']
crime_diff.sort_values('Difference', ascending=False)[0:10]
# Out:
#          County  Avg of First 5 Years  Avg of Last 5 Years  Difference
# 30  San Joaquin              0.005303             0.003649    0.001654
# 42       Tulare              0.005710             0.004208    0.001503
# 35       Shasta              0.003488             0.002398    0.001090
# 4        Colusa              0.004160             0.003092    0.001068
# 16  Los Angeles              0.003779             0.002799    0.000980
# 40       Tehama              0.004397             0.003455    0.000942
# 27   Sacramento              0.004356             0.003447    0.000909
# 39   Stanislaus              0.004892             0.003985    0.000907
# 22     Monterey              0.003770             0.002881    0.000888
# 7     El Dorado              0.003370             0.002496    0.000874

# %%
lowpriority_police = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Butte','Alameda','San Joaquin','Kings','Stanislaus','Tulare','Madera','Monterey','San Diego','Contra Costa']:
    lowpriority_police = pd.concat([lowpriority_police, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
lowpriority_police.head(5)
# Out:
#      Year County Violent Crime Arrests Estimated Population  \
# 2    2003  Butte                   571               209389
# 46   2004  Butte                   609               211419
# 90   2005  Butte                   635               212955
# 134  2006  Butte                   628               214690
# 178  2007  Butte                   743               216401
#
#      Arrests Per Capita
# 2              0.002727
# 46             0.002881
# 90             0.002982
# 134            0.002925
# 178            0.003433

# %%
fig, ax = plt.subplots(figsize=(5, 8))
ax.hist(priority_police['Arrests Per Capita'], bins=15, label="Highest Spending", alpha=0.8, color='darkgrey')
ax.hist(lowpriority_police['Arrests Per Capita'], bins=15, label="Lowest Spending", alpha=0.8, color='lightskyblue')
ax.legend()
ax.set_title('Distribution of Arrests in Counties With \n the Highest and Lowest Police Spending', horizontalalignment='center')
# Out:
# Text(0.5, 1.0, 'Distribution of Arrests in Counties With \n the Highest and Lowest Police Spending')

# %%
stats.ttest_ind(priority_police['Arrests Per Capita'], lowpriority_police['Arrests Per Capita'], equal_var=False)
# Out:
# Ttest_indResult(statistic=3.911600112166882, pvalue=0.0001133386588764183)

# %%
lowpriority_mentalhealth = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Ventura','Orange','El Dorado','Riverside','San Benito','Sacramento','Madera','Kings','San Diego','Calaveras']:
    lowpriority_mentalhealth = pd.concat([lowpriority_mentalhealth, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
lowpriority_mentalhealth.head(5)
# Out:
#      Year   County Violent Crime Arrests Estimated Population  \
# 43   2003  Ventura                  1967               784632
# 87   2004  Ventura                  1840               792213
# 131  2005  Ventura                  1967               795962
# 175  2006  Ventura                  2129               799049
# 219  2007  Ventura                  2290               803572
#
#      Arrests Per Capita
# 43             0.002507
# 87             0.002323
# 131            0.002471
# 175            0.002664
# 219            0.002850

# %%
fig, ax = plt.subplots(figsize=(5, 8))
ax.hist(priority_mentalhealth['Arrests Per Capita'], bins=15, label="Highest Spending", color='darkgrey', alpha=0.8)
ax.hist(lowpriority_mentalhealth['Arrests Per Capita'], bins=15, label="Lowest Spending", color='plum', alpha=0.8)
ax.legend()
ax.set_title('Distribution of Arrests in Counties With the \n Highest and Lowest Mental Health Spending')
# Out:
# Text(0.5, 1.0, 'Distribution of Arrests in Counties With the \n Highest and Lowest Mental Health Spending')

# %%
stats.ttest_ind(priority_mentalhealth['Arrests Per Capita'], lowpriority_mentalhealth['Arrests Per Capita'], equal_var=False)
# Out:
# Ttest_indResult(statistic=11.162675161385515, pvalue=5.8896204687557714e-24)

# %%
lowpriority_substanceabuse = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Madera','Orange','Monterey','Riverside','Kings','Solano','Contra Costa','Stanislaus','Imperial','El Dorado']:
    lowpriority_substanceabuse = pd.concat([lowpriority_substanceabuse, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
lowpriority_substanceabuse.head(5)
# Out:
#      Year  County Violent Crime Arrests Estimated Population  \
# 17   2003  Madera                   423               130641
# 61   2004  Madera                   430               134645
# 105  2005  Madera                   467               138174
# 149  2006  Madera                   513               141693
# 193  2007  Madera                   518               145163
#
#      Arrests Per Capita
# 17             0.003238
# 61             0.003194
# 105            0.003380
# 149            0.003621
# 193            0.003568

# %%
fig, ax = plt.subplots(figsize=(5, 8))
ax.hist(priority_substanceabuse['Arrests Per Capita'], bins=15, label="Highest Spending", color='darkgrey', alpha=0.8)
ax.hist(lowpriority_substanceabuse['Arrests Per Capita'], bins=15, label="Lowest Spending", color='mediumaquamarine', alpha=0.8)
ax.legend()
ax.set_title('Distribution of Arrests in Counties With the \n Highest and Lowest Substance Abuse Spending')
# Out:
# Text(0.5, 1.0, 'Distribution of Arrests in Counties With the \n Highest and Lowest Substance Abuse Spending')

# %%
stats.ttest_ind(priority_substanceabuse['Arrests Per Capita'], lowpriority_substanceabuse['Arrests Per Capita'], equal_var=False)
# Out:
# Ttest_indResult(statistic=7.2914229278721985, pvalue=3.2327279661610296e-12)

# %%
mean_pop = pd.DataFrame(population_pd.groupby('County').mean().reset_index())
mean_pop.drop('Year', axis=1, inplace=True)
mean_pop
# Out:
#              County    Population
# 0           Alameda  1.537114e+06
# 1            Amador  3.769894e+04
# 2             Butte  2.194614e+05
# 3         Calaveras  4.504006e+04
# 4            Colusa  2.124644e+04
# 5      Contra Costa  1.059757e+06
# 6         Del Norte  2.789181e+04
# 7         El Dorado  1.789074e+05
# 8             Glenn  2.809675e+04
# 9          Humboldt  1.338046e+05
# 10         Imperial  1.726915e+05
# 11             Inyo  1.852319e+04
# 12             Kern  8.272314e+05
# 13            Kings  1.484555e+05
# 14             Lake  6.412638e+04
# 15           Lassen  3.345900e+04
# 16      Los Angeles  9.946475e+06
# 17           Madera  1.482107e+05
# 18            Marin  2.543496e+05
# 19         Mariposa  1.814781e+04
# 20        Mendocino  8.809150e+04
# 21            Modoc  9.613250e+03
# 22         Monterey  4.209809e+05
# 23             Napa  1.361292e+05
# 24           Nevada  9.801544e+04
# 25           Orange  3.062321e+06
# ...

# %%
mean_arrests = pd.DataFrame(arrests_pd.groupby('COUNTY').mean().reset_index())
mean_arrests.drop('YEAR', axis=1, inplace=True)
pop_v_arrests = pd.concat([mean_pop, mean_arrests['violent_crime_arrests']], axis=1)
pop_v_arrests.sort_values('Population', inplace=True)
pop_v_arrests['Arrests Per Capita'] = pop_v_arrests['violent_crime_arrests'] / pop_v_arrests['Population']

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.scatter(pop_v_arrests['Population'][0:30], pop_v_arrests['Arrests Per Capita'][0:30])
ax.set_xlabel('Population', fontsize=15)
ax.set_ylabel('Arrests Per Capita', fontsize=15)
ax.set_title('Population vs. Arrests Per Capita (Outliers Removed)', fontsize=25)
plt.savefig('Pop v Arrests no outliers')

# %%
prop_priority_police = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Ventura', 'El Dorado', 'Riverside', 'Amador', 'Sacramento',
       'Calaveras', 'Inyo', 'Mariposa', 'Orange', 'Solano']:
    prop_priority_police = pd.concat([prop_priority_police, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
prop_priority_police.groupby('Year').mean('Arrests Per Capita').reset_index()
# Out:
#     Year  Arrests Per Capita
# 0   2003            0.003444
# 1   2004            0.003565
# 2   2005            0.003373
# 3   2006            0.003409
# 4   2007            0.003532
# 5   2008            0.003134
# 6   2009            0.003353
# 7   2010            0.003104
# 8   2011            0.002998
# 9   2012            0.002917
# 10  2013            0.002905
# 11  2014            0.002953
# 12  2015            0.003084
# 13  2016            0.003196
# 14  2017            0.003146
# 15  2018            0.002864

# %%
prop_priority_mentalhealth = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Butte', 'Alameda', 'Humboldt', 'Santa Cruz', 'Mendocino', 'Monterey',
       'Stanislaus', 'Imperial', 'Del Norte', 'Contra Costa']:
    prop_priority_mentalhealth = pd.concat([prop_priority_mentalhealth, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
prop_priority_mentalhealth.groupby('Year').mean('Arrests Per Capita').reset_index()
# Out:
#     Year  Arrests Per Capita
# 0   2003            0.004024
# 1   2004            0.004037
# 2   2005            0.003777
# 3   2006            0.003812
# 4   2007            0.003914
# 5   2008            0.003666
# 6   2009            0.003628
# 7   2010            0.003581
# 8   2011            0.003431
# 9   2012            0.003296
# 10  2013            0.003516
# 11  2014            0.003499
# 12  2015            0.003468
# 13  2016            0.003301
# 14  2017            0.003491
# 15  2018            0.003357

# %%
prop_priority_substanceabuse = pd.DataFrame(columns=['Year', 'County', 'Violent Crime Arrests', 'Estimated Population', 'Arrests Per Capita'])
for county in ['Modoc', 'Lake', 'Lassen', 'Trinity', 'Sonoma', 'Marin',
       'Napa', 'San Benito', 'San Luis Obispo', 'Glenn']:
    prop_priority_substanceabuse = pd.concat([prop_priority_substanceabuse, arrests_per_capita_pd.loc[arrests_per_capita_pd['County'] == county]])
prop_priority_substanceabuse.groupby('Year').mean('Arrests Per Capita').reset_index()
# Out:
#     Year  Arrests Per Capita
# 0   2003            0.003873
# 1   2004            0.003856
# 2   2005            0.003987
# 3   2006            0.003905
# 4   2007            0.003425
# 5   2008            0.003555
# 6   2009            0.003524
# 7   2010            0.003616
# 8   2011            0.003594
# 9   2012            0.004020
# 10  2013            0.003588
# 11  2014            0.003550
# 12  2015            0.003521
# 13  2016            0.003550
# 14  2017            0.003798
# 15  2018            0.003747

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.set_ylabel('Avg Annual Arrests Per Capita', fontsize=20)
ax.set_xlabel('Year', fontsize=20)
ax.set_title('Average Annual Arrests Per Capita by\nProportional Budget Prioritization', fontsize=25)

#ax.plot(avg_arrests_per_year['Year'], 
#        avg_arrests_per_year['Arrests Per Capita'],
#        label='Statewide Average', color='darkorange', linewidth=5)
sns.regplot(avg_arrests_per_year['Year'], 
        avg_arrests_per_year['Arrests Per Capita'],
            fit_reg=True, color='darkorange', label='Statewide Average', marker='o')

#ax.plot(prop_priority_police.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
#        prop_priority_police.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'], 
#        label='Police', color='lightskyblue')
sns.regplot(prop_priority_police.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
        prop_priority_police.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'],
           fit_reg=True, color='lightskyblue', label='Police', marker='o')

#ax.plot(prop_priority_mentalhealth.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
#        prop_priority_mentalhealth.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'], 
#        label='Mental Health', color='plum')
sns.regplot(prop_priority_mentalhealth.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
        prop_priority_mentalhealth.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'],
            fit_reg=True, color='plum', label='Mental Health', marker='o')

#ax.plot(prop_priority_substanceabuse.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
#        prop_priority_substanceabuse.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'], 
#        label='Substance Abuse', color='mediumaquamarine')
sns.regplot(prop_priority_substanceabuse.groupby('Year').mean('Arrests Per Capita').reset_index()['Year'], 
        prop_priority_substanceabuse.groupby('Year').mean('Arrests Per Capita')['Arrests Per Capita'],
           fit_reg=True, color='mediumaquamarine', label='Substance Abuse', marker='o')

ax.legend(loc='lower left')
plt.savefig('Proportional Budget Comparison')
# Out:
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /opt/conda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(15,5))

ax1.set_xticks(np.linspace(0, 0.01, 11))
ax1.hist(arrests_per_capita_pd['Arrests Per Capita'], bins=25, color='lightgrey', label='All Counties', alpha=0.5)
ax1.hist(prop_priority_police['Arrests Per Capita'], bins=25, color='lightskyblue', label='Police', alpha=0.5)
ax1.set_xlabel('Arrests Per Capita')
ax1.set_ylabel('Distribution of Annual Arrests')
ax1.legend()

ax2.set_xticks(np.linspace(0, 0.01, 11))
ax2.hist(arrests_per_capita_pd['Arrests Per Capita'], bins=25, color='lightgrey', label='All Counties', alpha=0.5)
ax2.hist(prop_priority_mentalhealth['Arrests Per Capita'], bins=25, color='plum', label='Mental Health', alpha=0.5)
ax2.set_xlabel('Arrests Per Capita')
ax2.set_ylabel('Distribution of Annual Arrests')
ax2.legend()

ax3.set_xticks(np.linspace(0, 0.01, 11))
ax3.hist(arrests_per_capita_pd['Arrests Per Capita'], bins=25, color='lightgrey', label='All Counties', alpha=0.5)
ax3.hist(prop_priority_substanceabuse['Arrests Per Capita'], bins=25, color='mediumaquamarine', label='Substance Abuse', alpha=0.5)
ax3.set_xlabel('Arrests Per Capita')
ax3.set_ylabel('Distribution of Annual Arrests')
ax3.legend()

fig.suptitle('Comparing Arrest Distribution in Counties With the Highest\nProportional Spending in Each Category Versus the Average for All Counties', fontsize=16, verticalalignment='top')
#plt.savefig('arrest distribution in priority counties v all counties')
# Out:
# Text(0.5, 0.98, 'Comparing Arrest Distribution in Counties With the Highest\nProportional Spending in Each Category Versus the Average for All Counties')

# %%
stats.ttest_ind(arrests_per_capita_pd['Arrests Per Capita'], prop_priority_police['Arrests Per Capita'], equal_var=False)
# Out:
# Ttest_indResult(statistic=3.6124628366587728, pvalue=0.0003584162490446959)

# %%
arrests_per_capita_pd['Arrests Per Capita'].mean()
# Out:
# 0.0034868711330536427

# %%
prop_priority_police['Arrests Per Capita'].mean()
# Out:
# 0.003186066078879086

# %%
stats.ttest_ind(arrests_per_capita_pd['Arrests Per Capita'], prop_priority_mentalhealth['Arrests Per Capita'], equal_var=False)
# Out:
# Ttest_indResult(statistic=-1.2179931846621062, pvalue=0.22447736253911266)

# %%
prop_priority_mentalhealth['Arrests Per Capita'].mean()
# Out:
# 0.0036124970025526544

# %%
stats.ttest_ind(arrests_per_capita_pd['Arrests Per Capita'], prop_priority_substanceabuse['Arrests Per Capita'], equal_var=False)
# Out:
# Ttest_indResult(statistic=-1.7987691790622635, pvalue=0.07347415618012836)

# %%
prop_priority_substanceabuse['Arrests Per Capita'].mean()
# Out:
# 0.0036941587221477035
