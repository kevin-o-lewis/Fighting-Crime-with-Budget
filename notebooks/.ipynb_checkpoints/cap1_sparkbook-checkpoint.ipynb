# %%
import pyspark as ps
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
spark = (ps.sql.SparkSession
         .builder
         .master('local[4]')
         .appName('crime_data')
         .getOrCreate()
        )
sc = spark.sparkContext

# %%
# !pwd
# Out:
# /home/jovyan/work/Capstone 1/CA-Violent-Crime

# %%
spark_arrests = spark.read.csv('data/DOJ_ArrestData1980-2019.csv',
                    header=True,
                    quote='"',
                    sep=",",
                    inferSchema=True)

# %%
spark_df.createOrReplaceTempView('arrests_tempview')

# %%
query = '''
select YEAR, COUNTY, SUM(VIOLENT) AS violent_crime_arrests
from arrests_tempview
where YEAR > 2002
and COUNTY != 'San Francisco County'
GROUP BY YEAR, COUNTY
ORDER BY YEAR, COUNTY
'''

arrests_sql = spark.sql(query)
arrests_sql.show()
arrests_pd = arrests_sql.toPandas()
# Out:
# +----+-------------------+---------------------+
# |YEAR|             COUNTY|violent_crime_arrests|
# +----+-------------------+---------------------+
# |2003|     Alameda County|                 4749|
# |2003|      Alpine County|                    7|
# |2003|      Amador County|                   92|
# |2003|       Butte County|                  571|
# |2003|   Calaveras County|                  166|
# |2003|      Colusa County|                   83|
# |2003|Contra Costa County|                 2482|
# |2003|   Del Norte County|                  154|
# |2003|   El Dorado County|                  614|
# |2003|      Fresno County|                 4939|
# |2003|       Glenn County|                  113|
# |2003|    Humboldt County|                  534|
# |2003|    Imperial County|                  640|
# |2003|        Inyo County|                   61|
# |2003|        Kern County|                 3746|
# |2003|       Kings County|                  677|
# |2003|        Lake County|                  319|
# |2003|      Lassen County|                   83|
# |2003| Los Angeles County|                39633|
# |2003|      Madera County|                  423|
# +----+-------------------+---------------------+
# only showing top 20 rows

# %%
arrests_pd.head(60)
# Out:
#     YEAR                  COUNTY  violent_crime_arrests
# 0   2003          Alameda County                   4749
# 1   2003           Alpine County                      7
# 2   2003           Amador County                     92
# 3   2003            Butte County                    571
# 4   2003        Calaveras County                    166
# 5   2003           Colusa County                     83
# 6   2003     Contra Costa County                   2482
# 7   2003        Del Norte County                    154
# 8   2003        El Dorado County                    614
# 9   2003           Fresno County                   4939
# 10  2003            Glenn County                    113
# 11  2003         Humboldt County                    534
# 12  2003         Imperial County                    640
# 13  2003             Inyo County                     61
# 14  2003             Kern County                   3746
# 15  2003            Kings County                    677
# 16  2003             Lake County                    319
# 17  2003           Lassen County                     83
# 18  2003      Los Angeles County                  39633
# 19  2003           Madera County                    423
# 20  2003            Marin County                    562
# 21  2003         Mariposa County                     78
# 22  2003        Mendocino County                    478
# 23  2003           Merced County                   1332
# 24  2003            Modoc County                     63
# 25  2003             Mono County                     45
# 26  2003         Monterey County                   1623
# 27  2003             Napa County                    347
# 28  2003           Nevada County                    263
# 29  2003           Orange County                   6646
# 30  2003           Placer County                    696
# 31  2003           Plumas County                    125
# 32  2003        Riverside County                   6200
# 33  2003       Sacramento County                   5647
# 34  2003       San Benito County                    233
# 35  2003   San Bernardino County                   8517
# 36  2003        San Diego County                   9602
# 37  2003      San Joaquin County                   3361
# 38  2003  San Luis Obispo County                    628
# 39  2003        San Mateo County                   1528
# 40  2003    Santa Barbara County                    882
# 41  2003      Santa Clara County                   5052
# 42  2003       Santa Cruz County                    849
# 43  2003           Shasta County                    726
# 44  2003           Sierra County                     13
# 45  2003         Siskiyou County                    220
# 46  2003           Solano County                   1609
# 47  2003           Sonoma County                   1126
# 48  2003       Stanislaus County                   2420
# 49  2003           Sutter County                    362
# 50  2003           Tehama County                    317
# 51  2003          Trinity County                     82
# 52  2003           Tulare County                   2265
# 53  2003         Tuolumne County                    162
# 54  2003          Ventura County                   1967
# 55  2003             Yolo County                    866
# 56  2003             Yuba County                    549
# 57  2004          Alameda County                   4301
# 58  2004           Alpine County                      7
# 59  2004           Amador County                    111

# %%
spark_capita = spark.read.csv('data/County_Expenditures_Per_Capita.csv',
                    header=True,
                    quote='"',
                    sep=",",
                    inferSchema=True)

# %%
spark_capita.createOrReplaceTempView('capita_tempview')

# %%
query = '''
select `Fiscal Year` as Year, `Entity Name` as County, `Estimated Population` AS Estimated_Population
from capita_tempview
ORDER BY Year, County
'''

capita_sql = spark.sql(query)
capita_sql.show()
capita_pd = capita_sql.toPandas()
# Out:
# +----+------------+--------------------+
# |Year|      County|Estimated_Population|
# +----+------------+--------------------+
# |2003|     Alameda|             1496218|
# |2003|      Alpine|                1208|
# |2003|      Amador|               36523|
# |2003|       Butte|              210367|
# |2003|   Calaveras|               42458|
# |2003|      Colusa|               19700|
# |2003|Contra Costa|              994908|
# |2003|   Del Norte|               27848|
# |2003|   El Dorado|              166030|
# |2003|      Fresno|              841423|
# |2003|       Glenn|               27071|
# |2003|    Humboldt|              128347|
# |2003|    Imperial|              150909|
# |2003|        Inyo|               18351|
# |2003|        Kern|              702873|
# |2003|       Kings|              136108|
# |2003|        Lake|               61307|
# |2003|      Lassen|               34955|
# |2003| Los Angeles|             9979618|
# |2003|      Madera|              131168|
# +----+------------+--------------------+
# only showing top 20 rows

# %%
capita_pd.head(60)
# Out:
#     Year           County  Estimated_Population
# 0   2003          Alameda               1496218
# 1   2003           Alpine                  1208
# 2   2003           Amador                 36523
# 3   2003            Butte                210367
# 4   2003        Calaveras                 42458
# 5   2003           Colusa                 19700
# 6   2003     Contra Costa                994908
# 7   2003        Del Norte                 27848
# 8   2003        El Dorado                166030
# 9   2003           Fresno                841423
# 10  2003            Glenn                 27071
# 11  2003         Humboldt                128347
# 12  2003         Imperial                150909
# 13  2003             Inyo                 18351
# 14  2003             Kern                702873
# 15  2003            Kings                136108
# 16  2003             Lake                 61307
# 17  2003           Lassen                 34955
# 18  2003      Los Angeles               9979618
# 19  2003           Madera                131168
# 20  2003            Marin                250409
# 21  2003         Mariposa                 17465
# 22  2003        Mendocino                 88222
# 23  2003           Merced                225138
# 24  2003            Modoc                  9335
# 25  2003             Mono                 13337
# 26  2003         Monterey                415773
# 27  2003             Napa                129776
# 28  2003           Nevada                 95749
# 29  2003           Orange               2978816
# 30  2003           Placer                275612
# 31  2003           Plumas                 20881
# 32  2003        Riverside               1705537
# 33  2003       Sacramento               1309611
# 34  2003       San Benito                 56309
# 35  2003   San Bernardino               1832966
# 36  2003        San Diego               2961579
# 37  2003      San Joaquin                613490
# 38  2003  San Luis Obispo                256254
# 39  2003        San Mateo                717041
# 40  2003    Santa Barbara                410277
# 41  2003      Santa Clara               1729917
# 42  2003       Santa Cruz                259844
# 43  2003           Shasta                172033
# 44  2003           Sierra                  3515
# 45  2003         Siskiyou                 44411
# 46  2003           Solano                411967
# 47  2003           Sonoma                472686
# 48  2003       Stanislaus                481604
# 49  2003           Sutter                 83241
# 50  2003           Tehama                 57684
# 51  2003          Trinity                 13319
# 52  2003           Tulare                386246
# 53  2003         Tuolumne                 56473
# 54  2003          Ventura                791310
# 55  2003             Yolo                181291
# 56  2003             Yuba                 62847
# 57  2004          Alameda               1498020
# 58  2004           Alpine                  1275
# 59  2004           Amador                 36834

# %%
query = '''
select YEAR, COUNTY, SUM(VIOLENT) AS violent_crime_arrests
from arrests_tempview
where YEAR > 2002
LEFT JOIN (select `Fiscal Year` as Year, `Entity Name` as County, `Estimated Population` AS Estimated_Population
from capita_tempview)
ON 
GROUP BY YEAR, COUNTY
ORDER BY violent_crime_arrests DESC
limit 100
'''

crime_per_capita_sql = spark.sql(query)
crime_per_capita_sql.show()
# Out:
# ---------------------------------------------------------------------------
# ParseException                            Traceback (most recent call last)
# <ipython-input-57-220f0ee07533> in <module>
#      11 '''
#      12
# ---> 13 crime_per_capita_sql = spark.sql(query)
#      14 crime_per_capita_sql.show()
#
# /usr/local/spark/python/pyspark/sql/session.py in sql(self, sqlQuery)
#     721         [Row(f1=1, f2='row1'), Row(f1=2, f2='row2'), Row(f1=3, f2='row3')]
#     722         """
# --> 723         return DataFrame(self._jsparkSession.sql(sqlQuery), self._wrapped)
#     724
#     725     def table(self, tableName):
#
# /usr/local/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# ParseException:
# mismatched input 'LEFT' expecting {<EOF>, ';'}(line 5, pos 0)
#
# == SQL ==
#
# select YEAR, COUNTY, SUM(VIOLENT) AS violent_crime_arrests
# from arrests_tempview
# where YEAR > 2002
# LEFT JOIN (select `Fiscal Year` as Year, `Entity Name` as County, `Estimated Population` AS Estimated_Population
# ^^^
# from capita_tempview)
# ON
# GROUP BY YEAR, COUNTY
# ORDER BY violent_crime_arrests DESC
# limit 100

# %%
spark_capita.show()
# Out:
# +-----------+-----------+------------------+--------------------+-----------------------+
# |Entity Name|Fiscal Year|Total Expenditures|Estimated Population|Expenditures Per Capita|
# +-----------+-----------+------------------+--------------------+-----------------------+
# |    Alameda|       2019|        3339008906|             1669301|                   2000|
# |    Alameda|       2018|        2937009130|             1660202|                   1769|
# |    Alameda|       2017|        2834852878|             1645359|                   1723|
# |    Alameda|       2016|        2466628582|             1627865|                   1515|
# |    Alameda|       2015|        2462509900|             1594569|                   1544|
# |    Alameda|       2014|        2405508090|             1573254|                   1529|
# |    Alameda|       2013|        2295382137|             1548681|                   1482|
# |    Alameda|       2012|        2221267982|             1532137|                   1450|
# |    Alameda|       2011|        2186575262|             1521157|                   1437|
# |    Alameda|       2010|        2083268145|             1574857|                   1323|
# |    Alameda|       2009|        2031238550|             1556657|                   1305|
# |    Alameda|       2008|        1944733831|             1543000|                   1260|
# |    Alameda|       2007|        1840512393|             1526148|                   1206|
# |    Alameda|       2006|        1789076569|             1510303|                   1185|
# |    Alameda|       2005|        1693220824|             1507500|                   1123|
# |    Alameda|       2004|        1649739744|             1498020|                   1101|
# |    Alameda|       2003|        1836243665|             1496218|                   1227|
# |     Alpine|       2019|          21924691|                1162|                  18868|
# |     Alpine|       2018|          18038469|                1154|                  15631|
# |     Alpine|       2017|          16806357|                1151|                  14602|
# +-----------+-----------+------------------+--------------------+-----------------------+
# only showing top 20 rows

# %%
spark_arrests.show()
# Out:
# +----+------+--------+-----------+--------------+-------+--------+---------+--------+----------+-------+-------+-------+
# |YEAR|GENDER|    RACE|  AGE_GROUP|        COUNTY|VIOLENT|PROPERTY|F_DRUGOFF|F_SEXOFF|F_ALLOTHER|F_TOTAL|M_TOTAL|S_TOTAL|
# +----+------+--------+-----------+--------------+-------+--------+---------+--------+----------+-------+-------+-------+
# |1980|  Male|   Black|   Under 18|Alameda County|    505|    1351|      188|      26|        79|   2149|   2286|    295|
# |1980|  Male|   Black|   18 to 19|Alameda County|    205|     465|      183|       8|        48|    909|   1333|      0|
# |1980|  Male|   Black|   20 to 29|Alameda County|    949|    1593|      606|      27|       178|   3353|   7974|      0|
# |1980|  Male|   Black|   30 to 39|Alameda County|    450|     755|      241|      18|       110|   1574|   4876|      0|
# |1980|  Male|   Black|   40 to 69|Alameda County|    172|     218|      117|      11|        66|    584|   3836|      0|
# |1980|  Male|   Black|70 and over|Alameda County|      4|       2|        2|       0|         0|      8|     79|      0|
# |1980|  Male|Hispanic|   Under 18|Alameda County|    151|     365|       40|       9|        77|    642|   1303|    187|
# |1980|  Male|Hispanic|   18 to 19|Alameda County|     83|      89|       48|       0|        58|    278|    963|      0|
# |1980|  Male|Hispanic|   20 to 29|Alameda County|    226|     243|      158|      13|        86|    726|   3748|      0|
# |1980|  Male|Hispanic|   30 to 39|Alameda County|     59|      80|       41|       8|        33|    221|   1669|      0|
# |1980|  Male|Hispanic|   40 to 69|Alameda County|     30|      16|       16|       4|        13|     79|   1287|      0|
# |1980|  Male|Hispanic|70 and over|Alameda County|      0|       0|        2|       0|         0|      2|     13|      0|
# |1980|  Male|   Other|   Under 18|Alameda County|     40|      78|        7|       2|        15|    142|    309|     37|
# |1980|  Male|   Other|   18 to 19|Alameda County|     15|      29|       10|       0|        14|     68|    191|      0|
# |1980|  Male|   Other|   20 to 29|Alameda County|     36|      54|       30|       4|        22|    146|    828|      0|
# |1980|  Male|   Other|   30 to 39|Alameda County|     22|      19|        9|       2|         9|     61|    511|      0|
# |1980|  Male|   Other|   40 to 69|Alameda County|      9|      10|        1|       1|         2|     23|    361|      0|
# |1980|  Male|   Other|70 and over|Alameda County|      0|       0|        0|       1|         0|      1|      8|      0|
# |1980|  Male|   White|   Under 18|Alameda County|    204|    1237|      145|      31|       117|   1734|   3861|    695|
# |1980|  Male|   White|   18 to 19|Alameda County|    120|     373|      175|       5|       114|    787|   2997|      0|
# +----+------+--------+-----------+--------------+-------+--------+---------+--------+----------+-------+-------+-------+
# only showing top 20 rows

# %%
combine = arrests_pd.join(capita_pd)

# %%
combine['COUNTY'] = combine['County']
#combine.drop('Year', axis=1, inplace=True)
#combine.drop('County', axis=1, inplace=True)
combine.head(20)
# Out:
#     YEAR        COUNTY  violent_crime_arrests  Estimated_Population
# 0   2003       Alameda                   4749               1496218
# 1   2003        Alpine                      7                  1208
# 2   2003        Amador                     92                 36523
# 3   2003         Butte                    571                210367
# 4   2003     Calaveras                    166                 42458
# 5   2003        Colusa                     83                 19700
# 6   2003  Contra Costa                   2482                994908
# 7   2003     Del Norte                    154                 27848
# 8   2003     El Dorado                    614                166030
# 9   2003        Fresno                   4939                841423
# 10  2003         Glenn                    113                 27071
# 11  2003      Humboldt                    534                128347
# 12  2003      Imperial                    640                150909
# 13  2003          Inyo                     61                 18351
# 14  2003          Kern                   3746                702873
# 15  2003         Kings                    677                136108
# 16  2003          Lake                    319                 61307
# 17  2003        Lassen                     83                 34955
# 18  2003   Los Angeles                  39633               9979618
# 19  2003        Madera                    423                131168

# %%
combine['arrests_per_capita'] = combine['violent_crime_arrests'] / combine['Estimated_Population']

# %%
combine.rename(columns = {'YEAR': 'Year', 'COUNTY': 'County', 'violent_crime_arrests': 'Violent Crime Arrests', 'arrests_per_capita': 'Arrests Per Capita', 'Estimated_Population': 'Estimated Population'}, inplace=True)

# %%
#combine.to_csv('Combined DataFrame Violent Crime Per Capita by County.csv')

# %%
d = {}
for county in combine['County'].unique():
    d[county] = list(combine[combine.County==county]['Arrests Per Capita'].values)

# %%
fig, ax = plt.subplots(figsize=(10, 15))
ax.boxplot(d.values(), vert=False, showfliers=False, patch_artist=True,
            boxprops=dict(facecolor='lightgrey', color='black'),
            capprops=dict(color='black'),
            whiskerprops=dict(color='black'),
            flierprops=dict(color='red', markeredgecolor='red'),
            medianprops=dict(color='red'))

ax.set_yticklabels(d.keys(), fontsize=12)
ax.set_xlabel('Violent Crime Arrests Per Capita 2003-2019', fontsize=15, labelpad=5)
ax.set_title('Violent Crime Statistics By County', fontsize=25, pad=15)
ax.grid(linestyle=':')
fig.tight_layout()
#plt.savefig('crime_boxplot')
